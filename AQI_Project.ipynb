# %% [markdown]
# # CMSC320 - Final Project (need better title)
# Michael Reeve and Sambit Sahoo

# %%
# imports
import pandas as pd

# %%
df_final = pd.DataFrame()

for i in range(12,23):
    curr_df = pd.read_csv(f"aqi_data_by_year/annual_aqi_by_county_20{i}.csv")
    df_final = pd.concat([df_final, curr_df])

df_final
# Out:
#        State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0    Alabama     Baldwin  2012            284        226             56
# 1    Alabama        Clay  2012            121         99             22
# 2    Alabama     Colbert  2012            283        222             55
# 3    Alabama      DeKalb  2012            361        282             74
# 4    Alabama      Elmore  2012            245        212             33
# ..       ...         ...   ...            ...        ...            ...
# 961  Wyoming    Sublette  2022            243        208             34
# 962  Wyoming  Sweetwater  2022            212        176             35
# 963  Wyoming       Teton  2022            213        200             13
# 964  Wyoming       Uinta  2022            181        179              2
# 965  Wyoming      Weston  2022            181        179              2
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                      2               0                    0
# 1                                      0               0                    0
# 2                                      6               0                    0
# 3                                      5               0                    0
# 4                                      0               0                    0
# ..                                   ...             ...                  ...
# 961                                    1               0                    0
# 962                                    0               1                    0
# 963                                    0               0                    0
# 964                                    0               0                    0
# 965                                    0               0                    0
#
#      Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0                 0      112                   61          38        0
# 1                 0       72                   56          35        0
# 2                 0      136                   62          40        0
# 3                 0      115                   64          40        0
# 4                 0      100                   54          40        0
# ..              ...      ...                  ...         ...      ...
# 961               0      105                   54          46        0
# 962               0      157                   57          43        0
# 963               0      100                   48          44        1
# 964               0       55                   17           6        0
# 965               0       58                   44          40        0
#
#      Days NO2  Days Ozone  Days PM2.5  Days PM10
# 0           0         210          74          0
# 1           0           0         121          0
# 2           0         209          74          0
# 3           0         320          41          0
# 4           0         245           0          0
# ..        ...         ...         ...        ...
# 961         0         242           1          0
# 962         0         152          31         29
# 963         1         209           2          0
# 964         0           0           0        181
# 965         0         181           0          0
#
# [11243 rows x 18 columns]
